# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## <center>Objectives</center>
# <ol>
#     <li style='font-size: 17px; padding:10px'>Find all episodes with a writer of “Greg Daniels” and assign the resulting DataFrame to a “written_by_greg” variable</li>
#     <li style='font-size: 17px; padding:10px'>Find all episode Before season 8 and assign result to a “good_episode” variable</li>
#     <li style='font-size: 17px; padding:10px'>Find all episodes that date before 1/1/2008 and assign the result to an “early_episodes”</li>
#     <li style='font-size: 17px; padding:10px'>Find all episodes with a Viewership greater than 10 who are also directed by Jeffrey Blitz and assign the results to a “jeffs_episodes” variable</li>
#     <li style='font-size: 17px; padding:10px'>Find all episodes in season 5 that have an episode number greater or equal than 13 and assign the results to a “second_half_of_season_5”</li>
#     <li style='font-size: 17px; padding:10px'>Find all episodes that were the 6th episode of their season also aired before 01/01/2012 and assign the results to a “sixth_episodes_of_early_seasons”</li>
#     <li style='font-size: 17px; padding:10px'>Find all episodes that were either in season 4 or directed by Harold Ramis</li>
#     <li style='font-size: 17px; padding:10px'>Find all episodes that either the 9th episode of their season or had an episode Name of “Niagara”</li>
#     <li style='font-size: 17px; padding:10px'>Find all records released in either 1979,1989 or 1998</li>
# </ol>

# %%
df = pd.read_csv('the_office.csv', index_col='Unnamed: 0')
df_copy = df.copy()

# %%
df.head()
# Out:
#    Season   EpisodeTitle                                              About  \
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 1       1  Diversity Day  Michael's off color remark puts a sensitivity ...
# 2       1    Health Care  Michael leaves Dwight in charge of picking the...
# 3       1   The Alliance  Just for a laugh, Jim agrees to an alliance wi...
# 4       1     Basketball  Michael and his staff challenge the warehouse ...
#
#    Ratings  Votes  Viewership  Duration            Date GuestStars  \
# 0      7.5   4936        11.2        23   24 March 2005        NaN
# 1      8.3   4801         6.0        23   29 March 2005        NaN
# 2      7.8   4024         5.8        22    5 April 2005        NaN
# 3      8.1   3915         5.4        23   12 April 2005        NaN
# 4      8.4   4294         5.0        23   19 April 2005        NaN
#
#           Director                                           Writers
# 0       Ken Kwapis  Ricky Gervais |Stephen Merchant and Greg Daniels
# 1       Ken Kwapis                                       B. J. Novak
# 2  Ken Whittingham                                  Paul Lieberstein
# 3     Bryan Gordon                                     Michael Schur
# 4     Greg Daniels                                      Greg Daniels

# %% [markdown]
# # <center>Cleaning</center>

# %% [markdown]
# ## Converting Date column from string to DateTime type

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#    Season   EpisodeTitle                                              About  \
# 0       1          Pilot  The premiere episode introduces the boss and s...
# 1       1  Diversity Day  Michael's off color remark puts a sensitivity ...
# 2       1    Health Care  Michael leaves Dwight in charge of picking the...
# 3       1   The Alliance  Just for a laugh, Jim agrees to an alliance wi...
# 4       1     Basketball  Michael and his staff challenge the warehouse ...
#
#    Ratings  Votes  Viewership  Duration       Date GuestStars  \
# 0      7.5   4936        11.2        23 2005-03-24        NaN
# 1      8.3   4801         6.0        23 2005-03-29        NaN
# 2      7.8   4024         5.8        22 2005-04-05        NaN
# 3      8.1   3915         5.4        23 2005-04-12        NaN
# 4      8.4   4294         5.0        23 2005-04-19        NaN
#
#           Director                                           Writers
# 0       Ken Kwapis  Ricky Gervais |Stephen Merchant and Greg Daniels
# 1       Ken Kwapis                                       B. J. Novak
# 2  Ken Whittingham                                  Paul Lieberstein
# 3     Bryan Gordon                                     Michael Schur
# 4     Greg Daniels                                      Greg Daniels

# %% [markdown]
# ## Adding episode number to data frame

# %%
episode_lists = np.zeros(df.shape[0])
episode = 1
current_season = 0
for row_index in df.index.values:
    if df.iloc[row_index]['Season'] == current_season:
        episode += 1
        episode_lists[row_index] = episode
        current_season = df.iloc[row_index]['Season']
    else:
        episode = 1
        episode_lists[row_index] = episode
        current_season = df.iloc[row_index]['Season']
df.insert(1, "Episode Number", episode_lists)
df['Episode Number'] = df['Episode Number'].astype('int')

# %% [markdown]
# ## <center>Objective 1</center>
# ### Find all episodes with a writer of “Greg Daniels” and assign the resulting DataFrame to a “written_by_greg” variable

# %%
filter_of_written_by_greg = df['Writers'].str.contains('Greg Daniels')
written_by_greg = df[filter_of_written_by_greg]
written_by_greg.head()
# Out:
#     Season  Episode Number         EpisodeTitle  \
# 0        1               1                Pilot
# 4        1               5           Basketball
# 10       2               5            Halloween
# 16       2              11         Booze Cruise
# 26       2              21  Conflict Resolution
#
#                                                 About  Ratings  Votes  \
# 0   The premiere episode introduces the boss and s...      7.5   4936
# 4   Michael and his staff challenge the warehouse ...      8.4   4294
# 10  Michael is pressured by corporate to fire some...      8.1   3392
# 16  The Dunder Mifflin staff go on a mandatory "bo...      8.6   3536
# 26  When Michael takes over conflict resolution du...      8.7   3253
#
#     Viewership  Duration       Date  GuestStars           Director  \
# 0         11.2        23 2005-03-24         NaN         Ken Kwapis
# 4          5.0        23 2005-04-19         NaN       Greg Daniels
# 10         8.0        30 2005-10-18         NaN          Paul Feig
# 16         8.7        22 2006-01-05  Rob Riggle         Ken Kwapis
# 26         7.4        22 2006-05-04         NaN  Charles McDougall
#
#                                              Writers
# 0   Ricky Gervais |Stephen Merchant and Greg Daniels
# 4                                       Greg Daniels
# 10                                      Greg Daniels
# 16                                      Greg Daniels
# 26                                      Greg Daniels

# %% [markdown]
# ## <center>Objective 2</center>
# ### Find all episode Before season 8 and assign result to a “good_episode” variable

# %%
filter_of_episodes_before_season_8 = df['Season'] < 8
good_episode = df[filter_of_episodes_before_season_8]
good_episode.tail()
# Out:
#      Season  Episode Number                         EpisodeTitle  \
# 136       7              20               Michael's Last Dundies
# 137       7              21                     Goodbye, Michael
# 138       7              22                     The Inner Circle
# 139       7              23  Dwight K. Schrute, (Acting) Manager
# 140       7              24                     Search Committee
#
#                                                  About  Ratings  Votes  \
# 136  Michael hosts his final "Dundies" as the boss ...      9.0   3039
# 137  As the office gets ready for Michael's final d...      9.8   8059
# 138  Tensions rise and feelings are hurt when Deang...      7.6   2183
# 139  When Jim rejects Jo's offer, Dwight becomes ac...      8.7   2414
# 140  The Scranton branch puts together a search com...      8.8   2623
#
#      Viewership  Duration       Date GuestStars       Director  \
# 136        6.85        23 2011-04-21        NaN   Mindy Kaling
# 137        8.42        50 2011-04-28        NaN      Paul Feig
# 138        6.90        23 2011-05-05        NaN      Matt Sohn
# 139        6.45        23 2011-05-12        NaN    Troy Miller
# 140        7.29        42 2011-05-19        NaN  Jeffrey Blitz
#
#               Writers
# 136      Mindy Kaling
# 137      Greg Daniels
# 138    Charlie Grandy
# 139    Justin Spitzer
# 140  Paul Lieberstein

# %% [markdown]
# ## <center>Objective 3</center>
# ### Find all episodes that date before 1/1/2008 and assign the result to an “early_episodes”

# %%
specified_date_time = datetime.datetime(2008, 1, 1)
filter_all_episodes_before_specified_date = df['Date'] < specified_date_time
early_episodes = df[filter_all_episodes_before_specified_date]
early_episodes.tail()
# Out:
#     Season  Episode Number    EpisodeTitle  \
# 54       4               4           Money
# 55       4               5        Local Ad
# 56       4               6     Branch Wars
# 57       4               7    Survivor Man
# 58       4               8  The Deposition
#
#                                                 About  Ratings  Votes  \
# 54  As Jan renovates the condo, Michael confronts ...      8.7   3073
# 55  Michael tries to make a local Dunder Mifflin c...      8.8   3125
# 56  Michael and Dwight try to play a prank on Kare...      8.5   2878
# 57  After Michael isn't invited to a camping trip ...      8.2   2775
# 58  Michael is put in an awkward position when Jan...      8.7   2923
#
#     Viewership  Duration       Date GuestStars          Director  \
# 54        8.50        42 2007-10-18        NaN  Paul Lieberstein
# 55        8.98        22 2007-10-25        NaN     Jason Reitman
# 56        8.39        30 2007-11-01        NaN       Joss Whedon
# 57        8.29        30 2007-11-08        NaN         Paul Feig
# 58        8.86        30 2007-11-15        NaN     Julian Farino
#
#              Writers
# 54  Paul Lieberstein
# 55       B. J. Novak
# 56      Mindy Kaling
# 57      Steve Carell
# 58      Lester Lewis

# %% [markdown]
# ## <center>Objective 4</center>
# ### Find all episodes with a Viewership greater than 10 who are also directed by Jeffrey Blitz and assign the results to a “jeffs_episodes” variable

# %%
filter_episode_vs_grater_10 = df['Viewership'] > 10
filter_episodes_directed_by_jeffery = df['Director'].str.contains('Jeffrey Blitz')
jeffs_episodes = df[filter_episode_vs_grater_10 & filter_episodes_directed_by_jeffery]
jeffs_episodes.head()
# Out:
#     Season  Episode Number   EpisodeTitle  \
# 77       5              13  Stress Relief
#
#                                                 About  Ratings  Votes  \
# 77  Dwight's too-realistic fire alarm gives Stanle...      9.7   8170
#
#     Viewership  Duration       Date  \
# 77       22.91        60 2009-02-01
#
#                                    GuestStars       Director           Writers
# 77  Cloris Leachman, Jack Black, Jessica Alba  Jeffrey Blitz  Paul Lieberstein

# %% [markdown]
# ## <center>Objective 5</center>
# ### Find all episodes in season 5 that have an episode number greater or equal than 13 and assign the results to a “second_half_of_season_5”

# %%
filter_season_5 = df['Season'] == 5
filter_episode_number_grater_equal_13 = df['Episode Number'] >= 13
second_half_of_season_5 = df[filter_season_5 & filter_episode_number_grater_equal_13]
second_half_of_season_5.head()
# Out:
#     Season  Episode Number             EpisodeTitle  \
# 77       5              13            Stress Relief
# 78       5              14  Lecture Circuit: Part 1
# 79       5              15  Lecture Circuit: Part 2
# 80       5              16              Blood Drive
# 81       5              17            Golden Ticket
#
#                                                 About  Ratings  Votes  \
# 77  Dwight's too-realistic fire alarm gives Stanle...      9.7   8170
# 78  While on lecture tour to other Dunder Mifflin ...      8.2   2474
# 79  Michael and Pam go to Nashua and discover that...      8.1   2431
# 80  Michael holds a lonely hearts party on Valenti...      8.0   2464
# 81  Michael asks Dwight to be the scapegoat for on...      8.7   2667
#
#     Viewership  Duration       Date  \
# 77       22.91        60 2009-02-01
# 78        8.39        30 2009-02-05
# 79        8.89        30 2009-02-12
# 80        8.63        22 2009-03-05
# 81        7.51        30 2009-03-12
#
#                                    GuestStars         Director  \
# 77  Cloris Leachman, Jack Black, Jessica Alba    Jeffrey Blitz
# 78                                        NaN       Ken Kwapis
# 79                                        NaN       Ken Kwapis
# 80                                        NaN  Randall Einhorn
# 81                                        NaN  Randall Einhorn
#
#              Writers
# 77  Paul Lieberstein
# 78      Mindy Kaling
# 79      Mindy Kaling
# 80   Brent Forrester
# 81      Mindy Kaling

# %% [markdown]
# ## <center>Objective 6</center>
# ### Find all episodes that were the 6th episode of their season also aired before 01/01/2012 and assign the results to a “sixth_episodes_of_early_seasons”

# %%
specified_date_time_for_airing = datetime.datetime(2012, 1, 1)
filter_episode_6_of_all_seasons = df['Episode Number'] == 6
filter_episode_aired_before_specific_time = df['Date'] < specified_date_time_for_airing
sixth_episodes_of_early_seasons = df[filter_episode_6_of_all_seasons & filter_episode_aired_before_specific_time]
sixth_episodes_of_early_seasons.head()
# Out:
#     Season  Episode Number     EpisodeTitle  \
# 5        1               6         Hot Girl
# 11       2               6        The Fight
# 33       3               6           Diwali
# 56       4               6      Branch Wars
# 70       5               6  Customer Survey
#
#                                                 About  Ratings  Votes  \
# 5   Michael is just one of the many male staff who...      7.7   3854
# 11  Jim rallies the staff together to witness a sh...      8.1   3388
# 33  Michael encourages the entire Scranton branch ...      7.9   3082
# 56  Michael and Dwight try to play a prank on Kare...      8.5   2878
# 70  Dwight and Jim believe that something is suspi...      8.5   2717
#
#     Viewership  Duration       Date GuestStars          Director  \
# 5         4.80        23 2005-04-26  Amy Adams    Amy Heckerling
# 11        7.90        22 2005-11-01        NaN        Ken Kwapis
# 33        8.81        22 2006-11-02        NaN     Miguel Arteta
# 56        8.39        30 2007-11-01        NaN       Joss Whedon
# 70        8.35        22 2008-11-06        NaN  Stephen Merchant
#
#                             Writers
# 5                      Mindy Kaling
# 11  Gene Stupnitsky | Lee Eisenberg
# 33                     Mindy Kaling
# 56                     Mindy Kaling
# 70                     Lester Lewis

# %% [markdown]
# ## <center>Objective 7</center>
# ### Find all episodes that were either in season 4 or directed by Harold Ramis

# %%
filter_all_episode_of_season_4 = df['Season'] == 4
filter_directed_by_harold = df['Director'].str.contains('Harold Ramis')
harold_ramis_or_season_4_episodes = df[filter_all_episode_of_season_4 | filter_directed_by_harold]
harold_ramis_or_season_4_episodes.head()
# Out:
#     Season  Episode Number             EpisodeTitle  \
# 37       3              10     A Benihana Christmas
# 46       3              19          Safety Training
# 49       3              22              Beach Games
# 51       4               1                  Fun Run
# 52       4               2  Dunder Mifflin Infinity
#
#                                                 About  Ratings  Votes  \
# 37  Trouble among the members of the party plannin...      8.8   3343
# 46  Andy returns to the office after weeks of ange...      8.8   3164
# 49  Michael uses "beach day" at Dunder-Mifflin to ...      9.2   3641
# 51  Michael accidentally runs over Meridith in the...      8.8   3635
# 52  Michael feels threatened when Ryan returns to ...      8.3   2934
#
#     Viewership  Duration       Date GuestStars      Director  \
# 37        8.44        42 2006-12-14        NaN  Harold Ramis
# 46        7.71        21 2007-04-12        NaN  Harold Ramis
# 49        7.20        28 2007-05-10        NaN  Harold Ramis
# 51        9.70        42 2007-09-27        NaN  Greg Daniels
# 52        8.49        42 2007-10-04        NaN    Craig Zisk
#
#                             Writers
# 37                 Jennifer Celotta
# 46                      B. J. Novak
# 49  Jennifer Celotta | Greg Daniels
# 51                     Greg Daniels
# 52                    Michael Schur

# %% [markdown]
# ## <center>Objective 8</center>
# ### Find all episodes that either the 9th episode of their season or had an episode Name of “Niagara”

# %%
filter_ninth_episode = df['Episode Number'] == 9
filter_episode_name_niagara = df['EpisodeTitle'].str.contains('Niagara')
ninth_episode_of_season_or_episode_titile_niagara = df[filter_ninth_episode | filter_episode_name_niagara]
ninth_episode_of_season_or_episode_titile_niagara.head()
# Out:
#     Season  Episode Number         EpisodeTitle  \
# 14       2               9  E-Mail Surveillance
# 36       3               9          The Convict
# 59       4               9         Dinner Party
# 73       5               9          The Surplus
# 94       6               4      Niagara: Part 1
#
#                                                 About  Ratings  Votes  \
# 14  Michael decides to set up e-mail surveillance ...      8.4   3338
# 36  Michael learns that one of the new employees a...      8.3   3151
# 59  Michael invites Jim and Pam and Andy and Angel...      9.5   5601
# 73  Michael has to spend the office surplus by the...      8.8   2776
# 94  The Office travels to Niagara Falls to celebra...      9.4   4560
#
#     Viewership  Duration       Date GuestStars       Director  \
# 14        8.10        23 2005-11-22  Ken Jeong      Paul Feig
# 36        9.07        30 2006-11-30        NaN  Jeffrey Blitz
# 59        9.22        30 2008-04-10        NaN      Paul Feig
# 73        8.33        22 2008-12-04        NaN      Paul Feig
# 94        9.42        30 2009-10-08        NaN      Paul Feig
#
#                              Writers
# 14                  Jennifer Celotta
# 36  Ricky Gervais | Stephen Merchant
# 59   Gene Stupnitsky | Lee Eisenberg
# 73   Gene Stupnitsky | Lee Eisenberg
# 94       Greg Daniels | Mindy Kaling

# %% [markdown]
# ## <center>Objective 9</center>
# ### Find all records released in either 1979,1989 or 1998

# %% [markdown]
# ## What is going on???
# ## We didnt have any office in 1979 or 1989 or 1998
